# %% [markdown]
# <a href="https://colab.research.google.com/github/SLuis25/Simulaci-n-I/blob/main/M%C3%A9todo_Box_Muller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from random import random
from scipy.stats import norm

# %%
def BoxMuller(n):
  lista = []
  for _ in range(n):
    u1 = random()
    u2 = random()
    # Se asignan a R y theta los valores de las operaciones con los numeros aleatorios generados, mediante el uso de las formulas del metodo
    R = np.sqrt(-2*np.log(u1))
    theta = 2*np.pi*u2
    # Se calculan del mismo modo los valores de x e y
    x = R*np.cos(theta)
    y = R*np.sin(theta)
    # Agregamos los valores de x e y a la lista
    lista.append(x)
    lista.append(y)

  return lista

# %%
N = 100000
var = BoxMuller(N)

# %%
# Graficamos el histograma y función teórica
plt.hist(var, bins=100, density=True, alpha=0.6, label='Histograma')

# Generamos valores para el eje x dentro del rango de los datos
x = np.linspace(min(var), max(var), 1000)

# Calculamos la función de densidad normal teórica
pdf = norm.pdf(x, loc=0, scale=1)  # media=0, desviación estándar=1

# Curva teórica
plt.plot(x, pdf, 'r-', label='Normal estándar teórica')
plt.title("Distribución Normal Box-Muller")
plt.xlabel("x")
plt.ylabel("Densidad")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculamos el valor aproximado de la media, varianza y desviación estándar
print("Media aproximada: ", np.mean(var))
print("Varianza aproximada: ", np.var(var))
print("Desviacion estandar aproximada: ", np.std(var))
# Out:
# Media aproximada:  -0.00025708373814876674
# Varianza aproximada:  0.9989592081296019
# Desviacion estandar aproximada:  0.9994794685883257

# %%
mu = 0
sigma = 1

# Se calcula la exactitud de los calculos hechos mediante la simulacion contra los calculos hechos analiticamente
E_med = abs(np.mean(var)-mu)
E_var = abs(np.var(var)-sigma**2)
E_des = abs(np.std(var)-sigma)

# %%
print("El error absoluto de la media son: ", E_med)

print("\nEl error absoluto de la varianza son: ", E_var)

print("\nEl error absoluto de la desviacion estandar son: ", E_des)
# Out:
# El error absoluto de la media son:  0.00025708373814876674
#
# El error absoluto de la varianza son:  0.0010407918703980723
#
# El error absoluto de la desviacion estandar son:  0.0005205314116742965
